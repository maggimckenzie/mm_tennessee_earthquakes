# %%
from shapely.geometry import Point
import pandas as pd
import numpy as np
import geopandas as gpd
import matplotlib.pyplot as plt
import seaborn as sns
import folium
from folium.plugins import MarkerCluster, HeatMap, HeatMapWithTime
import ipywidgets as widgets
from IPython.display import HTML, display
from collections import defaultdict

# %%
eq_table = pd.read_csv('../Data/04_deadly_eq_mag_cleaned.csv', index_col=False)

# %%
eq_table
# Out:
#           origin (utc) present-day country and link to wikipedia article  \
# 0     1900-05-11 17:23                                             Japan
# 1     1900-07-12 06:25                                            Turkey
# 2     1900-10-29 09:11                                         Venezuela
# 3     1901-02-15 00:00                                             China
# 4     1901-03-31 07:11                                          Bulgaria
# ...                ...                                               ...
# 1335  2011-03-24 20:25                 Burma (see 2011 Burma earthquake)
# 1336  2011-04-07 14:32          Japan (see April 2011 Miyagi earthquake)
# 1337  2011-09-18 12:40                India (see 2011 Sikkim earthquake)
# 1338  2011-09-23 10:41                  Turkey (see 2011 Van earthquake)
# 1339  2018-08-05 19:46                 Indonesia (see Lombok earthquake)
#
#          lat     long depth (km) magnitude secondary effects  \
# 0     38.700  141.100          5  7.0 MJMA               NaN
# 1     40.300   43.100        NaN   5.9 Muk               NaN
# 2     11.000  -66.000          0    7.7 Mw               NaN
# 3     26.000  100.100          0    6.5 Ms               NaN
# 4     43.400   28.700        NaN   6.4 Muk               NaN
# ...      ...      ...        ...       ...               ...
# 1335     NaN      NaN        NaN    6.8 Mw               NaN
# 1336    38.2    140.0       66.0    7.1 Mw               NaN
# 1337  27.723   88.064       19.7    6.9 Mw                 L
# 1338    38.6     43.5        7.2    7.1 Mw               NaN
# 1339     NaN      NaN       31.0    6.9 Mw               NaN
#
#       pde shaking deaths  pde total deaths  utsu total deaths  \
# 0                    NaN               NaN                NaN
# 1                    NaN               NaN              140.0
# 2                    NaN               NaN                NaN
# 3                    NaN               NaN                NaN
# 4                    NaN               NaN                4.0
# ...                  ...               ...                ...
# 1335                 NaN               NaN                NaN
# 1336                 NaN               NaN                NaN
# 1337                 NaN               NaN                NaN
# 1338                 NaN               NaN                NaN
# 1339                 NaN               NaN                NaN
#
#       em-dat total deaths  other source deaths  deaths  original_magnitude  \
# 0                     NaN                  NaN     NaN                 7.0
# 1                     NaN                  NaN   140.0                 5.9
# 2                     NaN                  NaN     NaN                 7.7
# 3                     NaN                  NaN     NaN                 6.5
# 4                     NaN                  NaN     4.0                 6.4
# ...                   ...                  ...     ...                 ...
# 1335                  NaN                150.0   150.0                 6.8
# 1336                  NaN                  NaN     NaN                 7.1
# 1337                  NaN                111.0   111.0                 6.9
# 1338                  NaN                601.0   601.0                 7.1
# 1339                  NaN                  NaN     NaN                 6.9
#
#      original_magnitude_scale
# 0                        MJMA
# 1                         Muk
# 2                          Mw
# 3                          Ms
# 4                         Muk
# ...                       ...
# 1335                       Mw
# 1336                       Mw
# 1337                       Mw
# 1338                       Mw
# 1339                       Mw
#
# [1340 rows x 15 columns]

# %%
eq_table['origin (utc)'] = pd.to_datetime(eq_table['origin (utc)'])

# %%
eq_table['year'] = eq_table['origin (utc)'].dt.year

# %%
eq_table['present-day country and link to wikipedia article']
# Out:
# 0                                          Japan
# 1                                         Turkey
# 2                                      Venezuela
# 3                                          China
# 4                                       Bulgaria
#                           ...
# 1335           Burma (see 2011 Burma earthquake)
# 1336    Japan (see April 2011 Miyagi earthquake)
# 1337          India (see 2011 Sikkim earthquake)
# 1338            Turkey (see 2011 Van earthquake)
# 1339           Indonesia (see Lombok earthquake)
# Name: present-day country and link to wikipedia article, Length: 1340, dtype: object

# %%
eq_table['country'] = eq_table['present-day country and link to wikipedia article'].apply(lambda x: x.split(' (', 1)[0])

# %%
eq_table.iloc[1033]['country']
# Out:
# '(see 1997 Cariaco earthquake)'

# %%
eq_table.at[1033, 'country'] = 'Venezuela'

# %%
eq_table.groupby('country')['origin (utc)'].count().to_dict()
# Out:
# {'Afghanistan': 30,
#  'Albania': 7,
#  'Algeria': 21,
#  'Argentina': 11,
#  'Armenia': 2,
#  'Australia': 3,
#  'Azerbaijan': 5,
#  'Bangladesh': 7,
#  'Belgium': 1,
#  'Bolivia': 3,
#  'Bosnia and Herzegovina': 3,
#  'Brazil': 1,
#  'Bulgaria': 5,
#  'Burma': 11,
#  'Burundi': 1,
#  'Canada': 3,
#  'Chile': 44,
#  'China': 166,
#  'Colombia': 24,
#  'Costa Rica': 10,
#  'Cuba': 2,
#  'Cyprus': 3,
#  'Czech Republic': 1,
#  'Democratic Republic of the Congo': 6,
#  'Djibouti': 1,
#  'Dominican Republic': 5,
#  'Ecuador': 19,
#  'Egypt': 4,
#  'El Salvador': 7,
#  'England': 1,
#  'Eritrea': 1,
#  'Ethiopia': 2,
#  'Fiji': 1,
#  'France': 4,
#  'Georgia': 9,
#  'Ghana': 1,
#  'Greece': 44,
#  'Guadeloupe': 1,
#  'Guatemala': 15,
#  'Guinea': 1,
#  'Haiti': 3,
#  'Honduras': 1,
#  'Hungary': 1,
#  'Iceland': 2,
#  'India': 25,
#  'Indonesia': 97,
#  'Iran': 91,
#  'Iran, 2005 Qeshm earthquake': 1,
#  'Iraq': 1,
#  'Italy': 37,
#  'Jamaica': 2,
#  'Japan': 82,
#  'Kazakhstan': 4,
#  'Kingdom of Yugoslavia': 1,
#  'Kyrgyzstan': 6,
#  'Macedonia': 1,
#  'Malawi': 2,
#  'Malaysia': 1,
#  'Mandatory Palestine and Transjordan': 1,
#  'Martinique': 1,
#  'Mexico': 46,
#  'Mongolia': 1,
#  'Montenegro': 1,
#  'Morocco': 7,
#  'Mozambique': 1,
#  'Nepal': 4,
#  'Netherlands': 1,
#  'New Zealand': 8,
#  'Nicaragua': 7,
#  'Pakistan': 26,
#  'Palestine': 1,
#  'Panama': 3,
#  'Papua New Guinea': 17,
#  'Peru': 54,
#  'Philippines': 39,
#  'Poland': 2,
#  'Portugal': 5,
#  'Puerto Rico': 1,
#  'Romania': 5,
#  'Russian Federation': 13,
#  'Rwanda': 1,
#  'Saint Pierre and Miquelon': 1,
#  'Samoa': 1,
#  'Saudi Arabia/Egypt': 1,
#  'Serbia': 1,
#  'Slovenia': 2,
#  'Solomon Islands': 5,
#  'South Africa': 14,
#  'Spain': 1,
#  'Sudan': 1,
#  'Syrian Arab Republic': 1,
#  'Taiwan': 48,
#  'Tajik Soviet Socialist Republic': 1,
#  'Tajikistan': 8,
#  'Tanzania': 4,
#  'Tunisia': 1,
#  'Turkey': 95,
#  'Turkmenistan': 4,
#  'US Territory of Alaska': 1,
#  'Uganda': 1,
#  'United States': 34,
#  'United States Minor Outlying Islands': 2,
#  'Uzbekistan': 4,
#  'Vanuatu': 2,
#  'Venezuela': 12,
#  'Vietnam': 1,
#  'Wallis and Futuna': 1,
#  'Yemen': 3,
#  'Yugoslavia': 1}

# %%
corr = eq_table.corr()

# %%
mask = np.triu(np.ones_like(corr, dtype=bool))

# %%
f, ax = plt.subplots(figsize=(11, 9))
cmap = sns.diverging_palette(230, 20, as_cmap=True)
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5},  alpha=.5);

# %%
sns.relplot(x='deaths', y='original_magnitude', data=eq_table, size='deaths', sizes=(40, 400), alpha=.5, palette="muted",);

# %% [markdown]
# # Doesn't appear to be a correlation between magnitude and deaths on overall

# %% [markdown]
# - Download Population data as CSV data from http://data.un.org/Data.aspx?q=population&d=PopDiv&f=variableID%3a12
# - Rename file to un_pop_data.csv

# %%
un_pop = pd.read_csv(r"../Data/un_pop_data.csv")

# %%
un_pop.columns
# Out:
# Index(['Country or Area', 'Year(s)', 'Variant', 'Value'], dtype='object')

# %%
un_pop_medium = un_pop[un_pop['Variant'] =='Medium']

# %%
un_pop_medium = un_pop_medium.rename(columns = {"Value": "population", "Year(s)": "year"})

# %%
un_pop_medium['country_join'] = un_pop_medium['Country or Area'].str.lower()

# %%
eq_table['country_join'] = eq_table['country'].str.lower()

# %%
eq_table['country_join']
# Out:
# 0           japan
# 1          turkey
# 2       venezuela
# 3           china
# 4        bulgaria
#           ...
# 1335        burma
# 1336        japan
# 1337        india
# 1338       turkey
# 1339    indonesia
# Name: country_join, Length: 1340, dtype: object

# %%
eq_table_pop = eq_table.merge(un_pop_medium, on=['country_join', 'year'])

# %%
eq_table_pop.shape
# Out:
# (278, 21)

# %%
eq_table_pop[['deaths', 'population']].corr()
# Out:
#               deaths  population
# deaths      1.000000    0.064417
# population  0.064417    1.000000

# %% [markdown]
# # in the matchable subset, there is a negative correlation with population

# %% [markdown]
# - Download GDP data as CSV data from http://data.un.org/Data.aspx?q=gdp&d=SNAAMA&f=grID%3a101%3bcurrID%3aUSD%3bpcFlag%3a1
# - Rename file to un_per_capita_gdp.csv

# %%
un_gdp = pd.read_csv(r"../data/un_per_capita_gdp.csv", skipfooter=2)
# Out:
# <ipython-input-25-bfa48b5609f6>:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   un_gdp = pd.read_csv(r"../data/un_per_capita_gdp.csv", skipfooter=2)

# %%
un_gdp = un_gdp.rename(columns = {"Value": "gdp", "Country or Area": "country", "Year": "year"})

# %%
un_gdp = un_gdp[un_gdp['Item']=='Gross Domestic Product (GDP)']

# %%
un_gdp['country_join'] = un_gdp['country'].str.lower()

# %%
un_gdp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9869 entries, 0 to 9868
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   country       9869 non-null   object
#  1   year          9869 non-null   int64
#  2   Item          9869 non-null   object
#  3   gdp           9869 non-null   float64
#  4   country_join  9869 non-null   object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 462.6+ KB

# %%
eq_table_gdp = eq_table.merge(un_gdp, on=['country_join', 'year'] )

# %%
eq_table_gdp.columns
# Out:
# Index(['origin (utc)', 'present-day country and link to wikipedia article',
#        'lat', 'long', 'depth (km)', 'magnitude', 'secondary effects',
#        'pde shaking deaths', 'pde total deaths', 'utsu total deaths',
#        'em-dat total deaths', 'other source deaths', 'deaths',
#        'original_magnitude', 'original_magnitude_scale', 'year', 'country_x',
#        'country_join', 'country_y', 'Item', 'gdp'],
#       dtype='object')

# %%
missing_countries = eq_table[~eq_table['country'].isin(eq_table_gdp['country_x'].to_list())]

# %%
missing_countries[missing_countries['country'].str.contains('Japan')]
# Out:
# Empty DataFrame
# Columns: [origin (utc), present-day country and link to wikipedia article, lat, long, depth (km), magnitude, secondary effects, pde shaking deaths, pde total deaths, utsu total deaths, em-dat total deaths, other source deaths, deaths, original_magnitude, original_magnitude_scale, year, country, country_join]
# Index: []

# %%
un_gdp[un_gdp['country'].str.contains('Japan')]
# Out:
#      country  year                          Item           gdp country_join
# 4585   Japan  2018  Gross Domestic Product (GDP)  39082.055125        japan
# 4586   Japan  2017  Gross Domestic Product (GDP)  38116.444637        japan
# 4587   Japan  2016  Gross Domestic Product (GDP)  38560.904712        japan
# 4588   Japan  2015  Gross Domestic Product (GDP)  34296.761817        japan
# 4589   Japan  2014  Gross Domestic Product (GDP)  37843.996580        japan
# 4590   Japan  2013  Gross Domestic Product (GDP)  40180.410720        japan
# 4591   Japan  2012  Gross Domestic Product (GDP)  48302.761503        japan
# 4592   Japan  2011  Gross Domestic Product (GDP)  47918.359458        japan
# 4593   Japan  2010  Gross Domestic Product (GDP)  44344.124576        japan
# 4594   Japan  2009  Gross Domestic Product (GDP)  40693.676587        japan
# 4595   Japan  2008  Gross Domestic Product (GDP)  39193.728236        japan
# 4596   Japan  2007  Gross Domestic Product (GDP)  35139.861729        japan
# 4597   Japan  2006  Gross Domestic Product (GDP)  35277.062163        japan
# 4598   Japan  2005  Gross Domestic Product (GDP)  37057.227911        japan
# 4599   Japan  2004  Gross Domestic Product (GDP)  37558.584013        japan
# 4600   Japan  2003  Gross Domestic Product (GDP)  34715.882889        japan
# 4601   Japan  2002  Gross Domestic Product (GDP)  32176.218716        japan
# 4602   Japan  2001  Gross Domestic Product (GDP)  33696.762874        japan
# 4603   Japan  2000  Gross Domestic Product (GDP)  38326.221477        japan
# 4604   Japan  1999  Gross Domestic Product (GDP)  35829.886386        japan
# 4605   Japan  1998  Gross Domestic Product (GDP)  31722.711932        japan
# 4606   Japan  1997  Gross Domestic Product (GDP)  34791.070643        japan
# 4607   Japan  1996  Gross Domestic Product (GDP)  38167.705379        japan
# 4608   Japan  1995  Gross Domestic Product (GDP)  43121.882174        japan
# 4609   Japan  1994  Gross Domestic Product (GDP)  38928.340322        japan
# 4610   Japan  1993  Gross Domestic Product (GDP)  35432.632086        japan
# 4611   Japan  1992  Gross Domestic Product (GDP)  31187.808060        japan
# 4612   Japan  1991  Gross Domestic Product (GDP)  28691.487279        japan
# 4613   Japan  1990  Gross Domestic Product (GDP)  25162.134966        japan
# 4614   Japan  1989  Gross Domestic Product (GDP)  24624.780283        japan
# 4615   Japan  1988  Gross Domestic Product (GDP)  24854.922268        japan
# 4616   Japan  1987  Gross Domestic Product (GDP)  20579.774128        japan
# 4617   Japan  1986  Gross Domestic Product (GDP)  16969.781298        japan
# 4618   Japan  1985  Gross Domestic Product (GDP)  11477.293940        japan
# 4619   Japan  1984  Gross Domestic Product (GDP)  10878.699661        japan
# 4620   Japan  1983  Gross Domestic Product (GDP)  10324.239584        japan
# 4621   Japan  1982  Gross Domestic Product (GDP)   9485.521361        japan
# 4622   Japan  1981  Gross Domestic Product (GDP)  10266.651927        japan
# 4623   Japan  1980  Gross Domestic Product (GDP)   9382.231547        japan
# 4624   Japan  1979  Gross Domestic Product (GDP)   9027.432087        japan
# 4625   Japan  1978  Gross Domestic Product (GDP)   8747.145630        japan
# 4626   Japan  1977  Gross Domestic Product (GDP)   6282.551660        japan
# 4627   Japan  1976  Gross Domestic Product (GDP)   5156.281056        japan
# 4628   Japan  1975  Gross Domestic Product (GDP)   4639.501126        japan
# 4629   Japan  1974  Gross Domestic Product (GDP)   4320.071896        japan
# 4630   Japan  1973  Gross Domestic Product (GDP)   3944.933749        japan
# 4631   Japan  1972  Gross Domestic Product (GDP)   2945.388030        japan
# 4632   Japan  1971  Gross Domestic Product (GDP)   2256.491111        japan
# 4633   Japan  1970  Gross Domestic Product (GDP)   2026.214670        japan

# %%
eq_table_gdp[['deaths', 'gdp']].corr()
# Out:
#           deaths       gdp
# deaths  1.000000 -0.031869
# gdp    -0.031869  1.000000

# %%
sns.scatterplot(x='deaths', y='gdp', data=eq_table_gdp[['deaths', 'gdp']])
# Out:
# <AxesSubplot:xlabel='deaths', ylabel='gdp'>

# %%
eq_table_gdp['log_deaths'] = np.log(eq_table_gdp['deaths'])
# Out:
# C:\Users\maggi\Anaconda3\envs\geospatial\lib\site-packages\pandas\core\series.py:726: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
eq_table_gdp
# Out:
#            origin (utc) present-day country and link to wikipedia article  \
# 0   1970-01-20 17:33:00                                             Japan
# 1   1970-02-05 22:05:00                                       Philippines
# 2   1970-04-07 05:34:00                                       Philippines
# 3   1970-03-28 21:02:00                Turkey (see 1970 Gediz earthquake)
# 4   1970-05-31 20:23:00                 Peru (see 1970 Ancash earthquake)
# ..                  ...                                               ...
# 613 2011-03-11 14:46:00                Japan (see 2011 Tōhoku earthquake)
# 614 2011-04-07 14:32:00          Japan (see April 2011 Miyagi earthquake)
# 615 2011-09-18 12:40:00                India (see 2011 Sikkim earthquake)
# 616 2011-09-23 10:41:00                  Turkey (see 2011 Van earthquake)
# 617 2018-08-05 19:46:00                 Indonesia (see Lombok earthquake)
#
#         lat     long depth (km) magnitude secondary effects  \
# 0    42.523  143.024       34.9    6.4 Ms               NaN
# 1    12.600  122.058        7.7    6.6 Ms               NaN
# 2    15.772  121.659       28.3    7.2 Mw               NaN
# 3    39.172   29.550       24.2   7.4 Muk               NaN
# 4    -9.248  -78.840         73   7.9 Muk                 L
# ..      ...      ...        ...       ...               ...
# 613  38.322  142.369       24.4    9.0 Mw                 T
# 614    38.2    140.0       66.0    7.1 Mw               NaN
# 615  27.723   88.064       19.7    6.9 Mw                 L
# 616    38.6     43.5        7.2    7.1 Mw               NaN
# 617     NaN      NaN       31.0    6.9 Mw               NaN
#
#      pde shaking deaths  pde total deaths  utsu total deaths  ...   deaths  \
# 0                   1.0               1.0                NaN  ...      1.0
# 1                   3.0               3.0                3.0  ...      3.0
# 2                  14.0              14.0               15.0  ...     15.0
# 3                1086.0            1086.0             1086.0  ...   1086.0
# 4                   0.0           70000.0            66794.0  ...  70000.0
# ..                  ...               ...                ...  ...      ...
# 613                 NaN               NaN                NaN  ...  15894.0
# 614                 NaN               NaN                NaN  ...      NaN
# 615                 NaN               NaN                NaN  ...    111.0
# 616                 NaN               NaN                NaN  ...    601.0
# 617                 NaN               NaN                NaN  ...      NaN
#
#      original_magnitude  original_magnitude_scale  year    country_x  \
# 0                   6.4                        Ms  1970        Japan
# 1                   6.6                        Ms  1970  Philippines
# 2                   7.2                        Mw  1970  Philippines
# 3                   7.4                       Muk  1970       Turkey
# 4                   7.9                       Muk  1970         Peru
# ..                  ...                       ...   ...          ...
# 613                 9.0                        Mw  2011        Japan
# 614                 7.1                        Mw  2011        Japan
# 615                 6.9                        Mw  2011        India
# 616                 7.1                        Mw  2011       Turkey
# 617                 6.9                        Mw  2018    Indonesia
#
#      country_join    country_y                          Item           gdp  \
# 0           japan        Japan  Gross Domestic Product (GDP)   2026.214670
# 1     philippines  Philippines  Gross Domestic Product (GDP)    207.049795
# 2     philippines  Philippines  Gross Domestic Product (GDP)    207.049795
# 3          turkey       Turkey  Gross Domestic Product (GDP)    717.749250
# 4            peru         Peru  Gross Domestic Product (GDP)    433.072260
# ..            ...          ...                           ...           ...
# 613         japan        Japan  Gross Domestic Product (GDP)  47918.359458
# 614         japan        Japan  Gross Domestic Product (GDP)  47918.359458
# 615         india        India  Gross Domestic Product (GDP)   1497.189524
# 616        turkey       Turkey  Gross Domestic Product (GDP)  11335.912705
# 617     indonesia    Indonesia  Gross Domestic Product (GDP)   3893.492690
#
#     log_deaths
# 0     0.000000
# 1     1.098612
# 2     2.708050
# 3     6.990257
# 4    11.156251
# ..         ...
# 613   9.673697
# 614        NaN
# 615   4.709530
# 616   6.398595
# 617        NaN
#
# [618 rows x 22 columns]

# %%
sns.scatterplot(x='log_deaths', y='gdp', data=eq_table_gdp[['log_deaths', 'gdp']])
# Out:
# <AxesSubplot:xlabel='log_deaths', ylabel='gdp'>

# %%
eq_table_gdp[['log_deaths', 'gdp']].corr()
# Out:
#             log_deaths       gdp
# log_deaths    1.000000 -0.117082
# gdp          -0.117082  1.000000

# %% [markdown]
# # FACT: Earthquakes don’t kill people, buildings and their contents do.

# %% [markdown]
# - Distance from the epicentre
# - Level of development
# - Population density
# - Time of day influences whether people are in their homes, at work or travelling.
# - The time of year and climate will influence survival rates and the rate at which disease can spread.
